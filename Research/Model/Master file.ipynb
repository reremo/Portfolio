# %%
# The installation should be run only once. Please comment them after the environment is complete.

# %%
conda install -c rdkit rdkit
# Out:
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: /
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
#                                                                                failed
#
# UnsatisfiableError: The following specifications were found
# to be incompatible with the existing python installation in your environment:
#
# Specifications:
#
#   - rdkit -> python[version='2.7.*|3.5.*|3.6.*|>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0|3.4.*']
#
# Your python: python=3.8
#
# If python is on the left-most side of the chain, that's the version you've asked for.
# When python appears to the right, that indicates that the thing on the left is somehow
# ...

# %%
conda create -c rdkit -n my-rdkit-env rdkit -y
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/raysmith/opt/anaconda3/envs/my-rdkit-env
#
#   added / updated specs:
#     - rdkit
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cairo-1.14.12              |       hc4e6be7_4         860 KB
#     fontconfig-2.13.0          |       h5d5b041_1         202 KB
#     libboost-1.73.0            |      ha68ee2f_10        12.7 MB
#     mkl-service-2.3.0          |   py37hfbe908c_0         201 KB
#     mkl_fft-1.2.0              |   py37hc64f4ea_0         141 KB
#     mkl_random-1.1.1           |   py37h959d312_0         284 KB
#     numpy-1.19.2               |   py37h456fd55_0          21 KB
#     numpy-base-1.19.2          |   py37hcfb5961_0         4.0 MB
#     olefile-0.46               |           py37_0          49 KB
#     pandas-1.1.3               |   py37hb1e8313_0         7.8 MB
# ...

# %%
conda activate my-rdkit-env
# Out:
# CommandNotFoundError: Your shell has not been properly configured to use 'conda activate'.
# To initialize your shell, run
#
#     $ conda init <SHELL_NAME>
#
# Currently supported shells are:
#   - bash
#   - fish
#   - tcsh
#   - xonsh
#   - zsh
#   - powershell
#
# See 'conda init --help' for more information and options.
#
# IMPORTANT: You may need to close and restart your shell after running 'conda init'.
#
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -n my-rdkit-env nb_conda_kernels
# Out:
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/raysmith/opt/anaconda3/envs/my-rdkit-env
#
#   added / updated specs:
#     - nb_conda_kernels
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     appnope-0.1.0              |           py37_0           8 KB
#     argon2-cffi-20.1.0         |   py37haf1e3a3_1          44 KB
#     async_generator-1.10       |   py37h28b3542_0          39 KB
#     cffi-1.14.3                |   py37hed5b41f_0         214 KB
#     entrypoints-0.3            |           py37_0          12 KB
#     ipykernel-5.3.4            |   py37h5ca1d4c_0         182 KB
# ...

# %%
# At this point shut down the notebook and re-open it using the new my-rdkit-env.
# Then proceesd installing the other depndencies

# %%
conda install pandas==0.22#conda install pandas==0.24
# Out:
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: /
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
#                                                                                failed
#
# UnsatisfiableError: The following specifications were found
# to be incompatible with the existing python installation in your environment:
#
# Specifications:
#
#   - pandas==0.22 -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0']
#
# Your python: python=3.7
#
# If python is on the left-most side of the chain, that's the version you've asked for.
# When python appears to the right, that indicates that the thing on the left is somehow
# ...

# %%
conda install -c conda-forge matplotlib
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/raysmith/opt/anaconda3/envs/my-rdkit-env
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2020.6.20  |       hecda079_0         146 KB  conda-forge
#     certifi-2020.6.20          |   py37h2987424_2         151 KB  conda-forge
#     cycler-0.10.0              |             py_2           9 KB  conda-forge
#     kiwisolver-1.3.0           |   py37h23ab428_0          52 KB
#     matplotlib-3.3.2           |   py37hc8dfbb8_1           6 KB  conda-forge
#     matplotlib-base-3.3.2      |   py37h181983e_0         5.1 MB
#     openssl-1.1.1h             |       haf1e3a3_0         1.9 MB  conda-forge
#     python_abi-3.7             |          1_cp37m           4 KB  conda-forge
# ...

# %%
conda install xlrd     #excel reader to import the database
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/raysmith/opt/anaconda3/envs/my-rdkit-env
#
#   added / updated specs:
#     - xlrd
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     openssl-1.1.1h             |       haf1e3a3_0         2.2 MB
#     xlrd-1.2.0                 |           py37_0         175 KB
#     ------------------------------------------------------------
#                                            Total:         2.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   xlrd               pkgs/main/osx-64::xlrd-1.2.0-py37_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    conda-forge::ca-certificates-2020.6.2~ --> pkgs/main::ca-certificates-2020.10.14-0
#   certifi            conda-forge/osx-64::certifi-2020.6.20~ --> pkgs/main/noarch::certifi-2020.6.20-pyhd3eb1b0_3
#
# ...

# %%
# !pip3 install --upgrade openpyxl
# Out:
# ...
#   Using cached openpyxl-3.0.5-py2.py3-none-any.whl (242 kB)
# ...
#   Created wheel for et-xmlfile: filename=et_xmlfile-1.0.1-py3-none-any.whl size=8917 sha256=88c1846d62f6dc7810b1c6e4c4f088465fa518ee74634d60eb2d7538a11af19a
#   Stored in directory: /Users/raysmith/Library/Caches/pip/wheels/e2/bd/55/048b4fd505716c4c298f42ee02dffd9496bb6d212b266c7f31
# Successfully built et-xmlfile
# ...

# %%
conda update rdkit
# Out:
# PackageNotInstalledError: Package is not installed in prefix.
#   prefix: /Users/raysmith/opt/anaconda3
#   package name: rdkit
#
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install scikit-learn==0.21
# Out:
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - scikit-learn==0.21
#
# Current channels:
#
#   - https://repo.anaconda.com/pkgs/main/osx-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/osx-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
#
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
#conda update scikit-learn

# %%
conda install joblib
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/raysmith/opt/anaconda3/envs/my-rdkit-env
#
#   added / updated specs:
#     - joblib
#
#
# The following NEW packages will be INSTALLED:
#
#   joblib             pkgs/main/noarch::joblib-0.17.0-py_0
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c mordred-descriptor mordred
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/raysmith/opt/anaconda3/envs/my-rdkit-env
#
#   added / updated specs:
#     - mordred
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     mordred-1.2.0              |     pyhe5148d4_0         257 KB  mordred-descriptor
#     ------------------------------------------------------------
#                                            Total:         257 KB
#
# The following NEW packages will be INSTALLED:
#
#   mordred            mordred-descriptor/noarch::mordred-1.2.0-pyhe5148d4_0
#   networkx           pkgs/main/noarch::networkx-2.5-py_0
#   tqdm               pkgs/main/noarch::tqdm-4.50.2-py_0
#
#
#
# ...
# mordred-1.2.0        | 257 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# ...

# %%
pip install sklearn-genetic
# Out:
# ...
#   Using cached sklearn_genetic-0.3.0-py2.py3-none-any.whl (10 kB)
# ...
#      |████████████████████████████████| 109 kB 10.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 7.2 MB 11.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 28.7 MB 11.3 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#At this point all dependencies are installed. The packages necessary for each notebook are loaded automatically.
#To store the results please create a folder named "results" and inside that folder ccreate one names "tables" and another named "figures"

# %%
# %run -t "../Jupyter/Data preprocessing.ipynb"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/Desktop/Jupyter/Data preprocessing.ipynb in <module>
#       1 smile_list = mols['SMILES'].values.tolist()
# ----> 2 mol_list = [Chem.MolFromSmiles(smile) for smile in smile_list]
#
# ~/Desktop/Jupyter/Data preprocessing.ipynb in <listcomp>(.0)
#       1 smile_list = mols['SMILES'].values.tolist()
# ----> 2 mol_list = [Chem.MolFromSmiles(smile) for smile in smile_list]
#
# TypeError: No registered converter was able to produce a C++ rvalue of type std::__1::basic_string<wchar_t, std::__1::char_traits<wchar_t>, std::__1::allocator<wchar_t> > from this Python object of type float
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-52e16d8c1418> in <module>
# ...

# %%
# %run -t "../Jupyter/Section I - Preliminary models.ipynb"
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/anaconda3/envs/my-rdkit-env/lib/python3.6/site-packages/IPython/core/magics/execution.py in run(self, parameter_s, runner, file_finder)
#     696             fpath = arg_lst[0]
# --> 697             filename = file_finder(fpath)
#     698         except IndexError:
#
# ~/anaconda3/envs/my-rdkit-env/lib/python3.6/site-packages/IPython/utils/path.py in get_py_filename(name, force_win32)
#     108     else:
# --> 109         raise IOError('File `%r` not found.' % name)
#     110
#
# OSError: File `'../Jupyter/Section I - Preliminary models.ipynb.py'` not found.
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-2-f70899b14fb2> in <module>
# ...

# %%
# %run -t "../Jupyter/Section II - Optimization.ipynb"
# Out:
# RMSE$_{CV_{DCAA}}$ = 1.18
# RMSE$_{CV_{DCAA}}$ = 1.17
# RMSE$_{CV_{TCAA}}$ = 1.30
# RMSE$_{CV_{TCAA}}$ = 1.30
# RMSE$_{CV_{sumHAAs}}$ = 1.50
# RMSE$_{CV_{sumHAAs}}$ = 1.49
# RMSE$_{CV}$ = 1.24
# RMSE$_{CV_{DCAA}}$ = 1.23
# RMSE$_{CV_{TCAA}}$ = 1.25
# RMSE$_{CV_{TCAA}}$ = 1.23
# RMSE$_{CV_{DCAA}}$ = 1.51
# RMSE$_{CV_{sumHAAs}}$ = 1.54
# \begin{tabular}{lrrrr}
# \toprule
# {} &     RMSE\_\{CV\} &           Q\textasciicircum 2 &    RMSE\_\{ext\} &     R\textasciicircum 2\_\{ext\} \\
# \midrule
# RF\_default        &  1.251773e+00 &  9.245122e-02 &  1.005326e+00 &  4.281965e-01 \\
# SVR\_\{rbf\}\_default &  1.194536e+00 &  2.629609e-01 &  9.932879e-01 &  4.418087e-01 \\
# L-SVR\_default     &  2.425589e+00 & -3.566707e+00 &  3.476350e+00 & -5.837224e+00 \\
# MLP\_default       &  1.510496e+00 & -4.918040e-01 &  1.241414e+00 &  1.281019e-01 \\
# MLR\_default       &  1.075434e+12 & -8.411860e+24 &  9.273674e+12 & -4.865600e+25 \\
# ...

# %%
# %run -t "../Jupyter/Section III - Selection of descriptors - clean lopp.ipynb"
